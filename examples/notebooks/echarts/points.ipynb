// %%
%useLatestDescriptors
%use kandy-echarts

// %% [markdown]
// ## Basic pointer chart

// %%
val df = dataFrameOf(
    "xAxis" to listOf(10.0,8.07,13.0,9.05,11.0,14.0,13.4,10.0,14.0,12.5,9.15,11.5,3.03,12.2,2.02,1.05,4.05,6.03,12.0,12.0,7.08,5.02),
    "yAxis" to listOf(8.04,6.95,7.58,8.81,8.33,7.66,6.81,6.33,8.96,6.82,7.2,7.2,4.23,7.83,4.47,3.33,4.96,7.24,6.26,8.84,5.82,5.6)
    )

// %%
df.plot { 
    x(xAxis)
    y(yAxis)

    points {}
}
// Out:
// <script>require.config({paths: {'echarts':'https://cdn.jsdelivr.net/npm/echarts@5.6.0/dist/echarts.min'}});</script><div id="17705070ea5f4bdf83f6c79480e54639" style="width:800px; height:600px;"></div><script>                require(['echarts'], function (echarts) {
//                     var chart_17705070ea5f4bdf83f6c79480e54639 = echarts.init(document.getElementById('17705070ea5f4bdf83f6c79480e54639'), {renderer: 'canvas'});
// var option_17705070ea5f4bdf83f6c79480e54639 = {"xAxis":{"type":"value"},"yAxis":{"type":"value"},"dataset":{"source":[["xAxis","yAxis"],[10.0,8.04],[8.07,6.95],[13.0,7.58],[9.05,8.81],[11.0,8.33],[14.0,7.66],[13.4,6.81],[10.0,6.33],[14.0,8.96],[12.5,6.82],[9.15,7.2],[11.5,7.2],[3.03,4.23],[12.2,7.83],[2.02,4.47],[1.05,3.33],[4.05,4.96],[6.03,7.24],[12.0,6.26],[12.0,8.84],[7.08,5.82],[5.02,5.6]]},"series":[{"type":"scatter","name":"xAxis yAxis","encode":{"x":"xAxis","y":["yAxis"]}}]};
// ...

// %%
val xa = listOf(3.275154,-3.344465,0.355083,1.852435,-2.078973,-0.993756,2.682252,-3.087776,-1.565978,2.441611,-0.659487,-0.459601,2.17768,-2.920969,-0.028814,3.625746,-3.912363,-0.551694,2.855808,-3.594448,0.421993,1.650821,-2.082902,-0.718809,4.513623,-4.822011,-0.656297,1.919901,-3.287749,-1.576936,3.598143,-3.977329,-1.79108,3.914654,-1.910108,-1.226597,1.148946,-2.113864,0.845762,2.629062,-1.640717,-1.881012,4.606999,-4.366462,0.765015,3.121904,-4.025139,-0.559558,4.376754,-1.874308,-0.089337,3.997787,-3.082978,0.845235,1.327224,-2.889949,-0.966018,2.960769,-3.275518,0.639276)
val ya = listOf(2.957587,2.603513,-3.376585,3.547351,2.552013,-0.884433,4.007573,2.878713,-1.256985,0.444826,3.111284,-2.618005,2.387793,2.917485,-4.168078,2.119041,1.325108,-2.814223,3.483301,2.856651,-2.372646,3.407572,3.384412,-2.492514,3.841029,4.607049,-1.449872,4.439368,3.918836,-2.977622,1.97597,4.900932,-2.184517,3.559303,4.166946,-3.317889,3.345138,3.548172,-3.589788,3.535831,2.990517,-2.485405,3.510312,4.023316,-3.00127,2.173988,4.65231,-3.840539,4.863579,4.032237,-3.026809,2.518662,2.884822,-3.454465,3.358778,3.596178,-2.839827,3.079555,1.577068,-3.4128)

val df = dataFrameOf(
    "x1" to xa.subList(0, 10),
    "y1" to ya.subList(0, 10),
    "x2" to xa.subList(10, 20),
    "y2" to ya.subList(10, 20),
    "x3" to xa.subList(20, 30),
    "y3" to ya.subList(20, 30),
    "x4" to xa.subList(30, 40),
    "y4" to ya.subList(30, 40),
    "x5" to xa.subList(40, 50),
    "y5" to ya.subList(40, 50),
    "x6" to xa.subList(50, 60),
    "y6" to ya.subList(50, 60),
    )

// %%
df.plot { 
    points { 
        x(x1)
        y(y1)
    }
    points { 
        x(x2)
        y(y2)
    }
    points { 
        x(x3)
        y(y3)
    }
    points { 
        x(x4)
        y(y4)
    }
    points { 
        x(x5)
        y(y5)
    }
    points { 
        x(x6)
        y(y6)
    }
}
// Out:
// <script>require.config({paths: {'echarts':'https://cdn.jsdelivr.net/npm/echarts@5.6.0/dist/echarts.min'}});</script><div id="05a2dab6f932471f8a80eaa7f2ceedb0" style="width:800px; height:600px;"></div><script>                require(['echarts'], function (echarts) {
//                     var chart_05a2dab6f932471f8a80eaa7f2ceedb0 = echarts.init(document.getElementById('05a2dab6f932471f8a80eaa7f2ceedb0'), {renderer: 'canvas'});
// ...

// %%
import java.util.Random

val random = Random(42)
val df = dataFrameOf(
    "xA" to List(10_000) { random.nextGaussian() },
    "yA" to List(10_000) { random.nextGaussian() }
    )

// %%
df.plot { 
    x(xA)
    y(yA)
    points {}
}
// Out:
// <script>require.config({paths: {'echarts':'https://cdn.jsdelivr.net/npm/echarts@5.6.0/dist/echarts.min'}});</script><div id="f79d0ffd53ae436b8c53d9870f95798d" style="width:800px; height:600px;"></div><script>                require(['echarts'], function (echarts) {
//                     var chart_f79d0ffd53ae436b8c53d9870f95798d = echarts.init(document.getElementById('f79d0ffd53ae436b8c53d9870f95798d'), {renderer: 'canvas'});
// ...

// %% [markdown]
// ## Customize points

// %%
val type = listOf("a", "b", "c", "d")
val df = dataFrameOf(
    "bs" to List(100) { random.nextInt(21) + 9 },
    "sp" to List(100) { random.nextInt(215) + 95 },
    "tp" to List(100) { type.random() },
    "sz" to List(100) { random.nextInt(30) + 5}
)

// %%
df.plot { 
    x(bs) { scale = continuous(limits = 5..35) }
    y(sp)

    points { 
        symbol = Symbol.DIAMOND
        color(tp)
        border { 
            color = Color.rgb(0, 0, 0)
        }

         size(sz) {
            scale = continuous(domain = 5..35, range = 10.0..35.0)
        }
    }


    layout {
        title.text = "Title"
        size = 800 to 600
    }
}
// Out:
// <script>require.config({paths: {'echarts':'https://cdn.jsdelivr.net/npm/echarts@5.6.0/dist/echarts.min'}});</script><div id="a884351217404c0bac863071a0237018" style="width:800px; height:600px;"></div><script>                require(['echarts'], function (echarts) {
//                     var chart_a884351217404c0bac863071a0237018 = echarts.init(document.getElementById('a884351217404c0bac863071a0237018'), {renderer: 'canvas'});
// ...
